# %%
import os
from langchain_huggingface import HuggingFaceEmbeddings
from langchain_pinecone import PineconeVectorStore

os.environ["PINECONE_API_KEY"] = "pcsk_3VGDSu_UVRTzxcbURQbqb2uxt4tdU7bXjUPg1hweQ4TGkDAtsyqytA65LyJtMybyuDNpwc"
INDEX_NAME = "rag-index"

embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-MiniLM-L6-v2")

vs = PineconeVectorStore.from_existing_index(
    index_name=INDEX_NAME,
    embedding=embeddings
)

docs = vs.similarity_search("What does the document say about X?", k=3)
for i, d in enumerate(docs, 1):
    print("----", i, "----")
    print(d.page_content[:400])
    print(d.metadata)
# Out:
# ---- 1 ----
# Proposition (Linearity of Gaussians) Given X ∼ N(µ,σ 2), and if
# a≠ 0, then aX+b∼ N(aµ+b,a 2σ2).
# Using this Y = X−µ
# σ is a standard gaussian.
# Conditioning on an event, and multiple continuous r.v.
# Deﬁnition (Conditional PDF given an event) Given a continuous
# random variable X and event A with P(A)> 0, we deﬁne the
# conditional PDF as the function that satisﬁes
# P(X ∈B/divides.alt0A)=/integral.dispB
# fX/divides.alt0A(x)dx.
# Deﬁnition (Conditional PDF given X ∈A) Given a continuous
# random variable X and an A⊂ R, with P(A)> 0:
# fX/divides.alt0X∈A(x)=
# /uni23A7/uni23AA/uni23AA/uni23A8/uni23AA/uni23AA/uni23A9
# 1
# P(A)fX(x), x ∈A,
# 0, x /slash.left∈A.
# Deﬁnition (Conditional expectation) Given a continuous random
# variableX and an event A, with P(A)> 0:
# E[X/divides.alt0A]=/integral.disp
# ∞
# −∞
# fX/divides.alt0A(x)dx.
# Deﬁnition (Memorylessness of the exponential random variable)
# When we condition an exponential random variable X on the event
# ...
